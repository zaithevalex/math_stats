# %% [markdown]
# <center>
# <img src="logo.png" height="900">
# </center>
#
#
# # Максимально правдоподобная домашка
#
# В этом задании мы с вами отточим метод максимального правдоподобия.

# %%
import numpy as np
import pandas as pd

from scipy import stats
from scipy.optimize import minimize

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Упражнение 1 (Разминка)
#
# __а)__ Пусть $X \sim Exp(0.05)$. Сгенерируйте из этого распределения выборку размера $1000$. У метода `rvs` используйте `random_state=42`
#
# Обратите внимание, что `stats.expon` принимает в качестве параметра `scale` значение $\frac{1}{\lambda}$, а $0.05$ это именно $\lambda$.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

x = stats.expon.rvs(scale = 20, size = 1000, random_state = 42)

# your code here
print(x, np.mean(x))
# Out:
# [9.38536180e+00 6.02024286e+01 2.63349139e+01 1.82588511e+01
#  3.39249741e+00 3.39192584e+00 1.19677537e+00 4.02246173e+01
#  1.83816431e+01 2.46250012e+01 4.15986160e-01 7.00711495e+01
#  3.57285909e+01 4.77375250e+00 4.01357977e+00 4.05222846e+00
#  7.25507459e+00 1.48785566e+01 1.13107413e+01 6.88445985e+00
#  1.89274175e+01 3.00469057e+00 6.91031024e+00 9.12554436e+00
#  1.21786938e+01 3.07587202e+01 4.45471724e+00 1.44405831e+01
#  1.79500944e+01 9.51276995e-01 1.87066604e+01 3.73922504e+00
#  1.34527862e+00 5.94737559e+01 6.74126068e+01 3.30466315e+01
#  7.26575720e+00 2.05554630e+00 2.30550153e+01 1.16018169e+01
#  2.60304468e+00 1.36709446e+01 6.99874429e-01 4.80084577e+01
#  5.98915554e+00 2.17251160e+01 7.47093163e+00 1.46822179e+01
#  1.58244760e+01 4.08777199e+00 6.98561427e+01 2.98449075e+01
#  5.61018884e+01 4.50430400e+01 1.82210882e+01 5.09887076e+01
#  1.85310918e+00 4.36269389e+00 9.25639314e-01 7.87064174e+00
#  9.84260584e+00 6.33120886e+00 3.52911573e+01 8.82453999e+00
#  6.59605680e+00 1.56481417e+01 3.03796296e+00 3.24096719e+01
#  1.54951738e+00 8.66829268e+01 2.95896755e+01 4.43078881e+00
#  1.10748408e-01 3.37979355e+01 2.45419181e+01 2.61132582e+01
#  2.95042905e+01 1.53858531e+00 8.87785345e+00 2.46300209e+00
#  3.97705914e+01 1.95260238e+01 8.03637603e+00 1.31336132e+00
#  7.44976701e+00 7.86628426e+00 2.61575157e+01 2.02977872e+01
#  4.36450382e+01 1.27813227e+01 2.54744787e+00 2.49825269e+01
#  2.86078551e+01 1.64777499e+01 2.94777993e+01 1.36162946e+01
#  1.47935768e+01 1.11562839e+01 5.14955480e-01 2.28334870e+00
#  6.38673626e-01 2.02345910e+01 7.54793418e+00 1.42087435e+01
#  4.76253106e+01 5.73477646e+00 1.05656395e+01 2.81749830e+01
#  5.19610314e+00 1.60208557e+00 6.84280608e+00 3.51616717e+00
#  5.30990017e+01 3.30177416e+01 2.00698838e+01 4.10303946e+01
#  3.25593788e+01 4.12990953e+00 4.46162681e+01 1.55019980e+01
#  3.29469658e+01 4.52848530e+01 7.65461433e+00 2.33184320e+00
#  5.17373492e+00 1.11411539e+01 3.40765945e+01 3.94268994e+01
#  1.39528184e-01 1.42975232e+01 1.08054664e+01 5.02334677e+00
#  2.55360783e+00 8.23817160e+00 5.72624225e+01 7.80767606e+00
#  1.46290561e+01 2.42817395e+01 9.03948998e+00 7.13559628e+01
#  6.56401973e+01 5.80122590e+00 1.37531856e+01 7.15860920e+00
#  6.70499353e+00 7.51689555e-01 1.88098414e+01 1.39703927e+01
#  1.05702175e+00 6.53251842e+00 4.77772190e+01 5.47721104e+00
#  3.13061722e+00 1.34454422e+01 8.48807397e+01 5.54289627e+00
#  2.23031002e+01 2.86777525e+01 5.42666345e+00 2.60549786e+01
#  9.17045599e+00 2.00100750e+01 2.00767565e+01 1.53477050e+01
#  1.89258318e+00 3.60728959e+01 7.73620587e+00 4.12864213e+00
#  8.32595196e-01 1.78755681e+01 2.26370347e+01 3.34538951e-01
#  1.43526117e+01 5.13648294e+00 2.07224868e+01 3.83208445e+00
#  2.34842506e+01 9.77917402e+00 5.52068764e+01 2.95888827e+00
#  8.34264868e+00 2.40888570e+00 5.17238079e+01 4.19666741e+01
#  5.96654740e+00 2.15752548e+01 3.39896815e+01 1.62026472e+01
#  1.50855882e+01 5.53754091e+00 1.95452281e+00 4.55024645e+01
#  4.61354886e+01 2.00533984e+01 8.28093020e+00 8.59135232e+00
#  2.58893086e+01 4.54819470e+01 4.36226514e+01 3.02712438e+01
#  2.05462139e+01 1.75783452e+00 3.52588429e+00 4.57646100e+01
#  1.86498789e+01 1.84792112e-01 2.13993803e+00 2.17832477e+01
#  1.01488741e-01 3.50631632e+00 1.59139569e+01 2.35463057e+01
#  2.11088296e+01 5.07899735e+00 2.49083458e+01 5.41647518e+00
#  7.87269818e+00 2.74471510e+01 2.09754763e+01 3.78391215e+01
#  2.14362658e+01 1.68008861e+01 1.96714123e+00 9.16832614e+00
#  6.16320296e+00 5.59400407e+00 7.22461881e+01 9.98774994e+00
#  4.45211042e+01 1.99466877e+01 3.16765051e+01 1.39687065e+01
#  1.72031181e+01 1.35658687e+01 4.34429791e+00 2.56352361e+01
#  6.59154737e+00 4.92329622e-01 2.07393757e+01 3.89867140e+00
#  5.64216629e+01 6.15512483e+01 4.92701977e+01 9.24574793e+00
#  3.11546307e-01 5.27104691e+01 1.11787655e+01 6.80168403e+01
#  6.62747095e+01 3.83477403e+01 6.97552136e+00 9.72583864e+00
#  3.80945330e+01 7.62292463e+00 3.71437233e+00 1.62747398e+01
#  5.50258694e+01 2.38165120e+01 1.68822467e+01 2.04456395e+00
#  1.90906143e+01 9.22113950e+01 3.01841173e+00 1.46099065e+01
#  4.19721728e+01 2.70006850e+01 2.38814885e+01 2.42457511e+01
#  8.90984685e+00 6.95124169e+00 3.31474901e+01 3.32265640e+01
#  4.03590009e+01 4.88923192e+01 1.43218647e+01 1.39236876e+01
#  3.20189986e+01 2.09943815e+01 2.42110130e+01 3.17723895e+01
#  4.41464695e+01 8.24964814e+00 9.41873577e+00 1.97392078e+00
#  1.72682805e+01 7.32082084e-01 1.25321390e+01 1.56458917e+01
#  6.75261321e+00 1.78726506e+01 6.19501242e-01 7.61269986e-01
#  3.45870274e+01 8.93170048e+00 2.71778083e+00 1.47730718e+01
#  2.93929588e+01 4.86236007e+00 1.95043924e+01 1.78422058e+00
#  1.06130192e+00 1.51581788e+01 1.55582089e+01 2.02907490e+01
#  2.58992113e+01 7.44711402e+01 1.45258224e+01 7.80039428e+00
#  3.17130796e+01 6.31702931e+00 1.15596686e+01 1.63410337e+00
#  5.13552191e-01 6.57475985e+01 3.61553528e+01 2.38128547e+01
#  1.05171929e+01 3.80613072e+00 3.40241483e+00 5.76011978e+00
#  1.59358130e+01 2.50769858e+01 2.15878070e+01 6.56824523e+00
#  6.19620700e+01 2.67803481e+01 1.61646096e+01 1.89206094e+01
#  1.08807573e+01 5.69322585e+00 8.80028259e+00 2.83636370e+01
#  2.89961594e-01 2.46760784e+00 9.41887539e-01 8.31629038e-01
#  3.86840607e+01 2.43248122e+01 1.28556919e+01 2.05913837e+00
#  1.35303593e+01 1.28290066e+01 3.80389426e+00 1.13779826e+01
#  1.01667323e+01 1.91344487e+01 2.01622907e+01 9.27246480e-01
#  9.38768009e+00 1.96624999e+01 1.39887891e+01 3.88269891e+01
#  2.14994953e+01 3.55705738e+00 1.46364873e+00 2.05678829e+01
#  5.37381453e-01 1.76269476e+01 5.63451091e+01 1.71356489e+01
#  9.82601384e+00 2.06165432e+01 1.22591195e+01 1.57762872e+01
#  5.67625429e+01 9.75855055e+00 6.49818372e+01 4.71515237e+01
#  4.35792522e+00 1.43768311e+00 2.12450671e+00 3.67797757e-01
#  1.98410023e+00 2.29774975e+01 1.47699254e+00 7.68314377e+00
#  3.72705208e+01 4.70940064e-01 3.36906101e+01 6.62166934e+00
#  2.51500240e+00 2.38631082e+01 1.98279835e+01 4.19883163e+01
#  2.65658716e+01 3.25399161e+01 6.62667725e+00 3.90666592e+00
#  2.77751279e+01 3.28841837e+01 9.31400978e+01 1.06415871e+01
#  9.30487824e+00 2.99590901e+01 8.33467342e+00 5.34027585e+01
#  3.90967831e+01 1.12071122e+01 2.77956943e+01 2.80926597e+01
#  2.17675038e+00 4.65689136e+01 1.40741498e+01 3.50266512e+01
#  7.71470852e+00 4.51758103e+01 9.85976908e+00 2.17936132e-01
#  4.71581459e+01 1.91451221e+00 7.69307267e+00 5.99394477e+01
#  6.01589908e+01 1.70399458e+01 1.99846016e+01 1.19002933e+01
#  6.94045557e+00 7.96972669e+00 2.23264716e+01 2.79167575e+01
#  3.13639083e+01 3.11766206e+01 1.91273893e+00 1.36409919e+01
#  1.18563413e+00 1.59492263e+01 1.16511055e+01 4.37323733e+01
#  8.64383239e+00 2.49011955e+00 3.08615309e+00 2.86686109e+01
#  1.92581136e+01 2.13217424e+00 1.75711043e+00 2.41441694e+01
#  1.51092179e+00 3.45037171e+01 2.44999951e+01 1.69697501e+00
#  1.77307736e+00 8.63091712e+01 9.37675165e+00 9.26110521e+00
#  3.35115081e+01 5.88432908e+01 8.53754788e+01 2.79979846e+01
#  9.44041999e+00 1.74387987e+00 3.00248508e+01 1.63472082e+01
#  1.10406625e+01 4.73647535e+01 2.35760416e+00 1.35701022e+01
#  2.28371789e-01 1.26470874e+01 1.15900862e+00 2.52981992e+00
#  2.50052464e+00 2.09513677e+01 2.74119544e+01 1.75110755e+01
#  6.54944042e+01 9.39593156e+00 6.72938315e+00 4.05900508e+01
#  5.06164135e+00 6.60574021e+01 2.44578887e-01 7.00505385e+01
#  8.82379972e-01 4.43544246e+01 1.50028650e+01 9.91365722e+01
#  1.53322752e+00 1.61421933e+01 6.96715044e+01 1.48088787e+01
#  1.98525658e+01 2.37980248e+01 1.21225551e+01 1.97534835e+01
#  1.75565172e+01 4.62846554e+01 9.30229235e-01 6.59685452e+00
#  6.00799201e+01 4.41935166e+01 1.21635052e+01 1.93586606e+01
#  6.49746840e+00 4.16808323e+00 1.24611720e+01 8.71907069e+00
#  1.75248741e+01 1.61844569e+00 7.32992025e+01 8.56773115e+01
#  2.39572776e+01 1.53615687e+01 7.40758603e+00 3.36181433e+01
#  2.30865917e+01 3.54947308e+00 4.83660218e+01 3.45798902e+01
#  5.98347705e+01 2.58720801e+01 1.90080804e+01 1.08340501e+01
#  5.39803672e+01 4.02078476e+01 9.25458773e-01 5.34416337e-01
#  9.44695523e+00 3.32729545e+01 8.72855094e+01 3.26019020e+00
#  1.80344826e+01 9.58947400e+00 7.00741711e+01 3.69182641e+01
#  3.64438009e+01 1.26483114e+01 1.07166987e+01 6.38777784e+00
#  1.16053928e+00 4.00085228e+01 3.35223488e+01 1.63448912e+02
#  1.13897468e+02 1.62130319e+01 2.93056618e+01 5.79234337e+01
#  3.78954403e+01 5.68304889e+00 1.19765365e+01 2.76592689e+00
#  6.16044757e+01 1.86369541e+01 5.19207451e+00 2.22765908e+01
#  1.92534087e+01 8.86840925e+00 2.41078243e+00 2.22688257e+01
#  1.46922085e+01 2.95961416e+01 1.46861972e+01 3.82354022e+01
#  1.60550824e+01 1.64622916e+01 4.18551729e+01 1.03329463e+01
#  2.87775911e+00 5.84100429e-01 2.81411491e+01 1.93679793e+01
#  2.43533070e+01 4.78962987e+00 2.93225102e+00 2.93029525e-01
#  8.63374523e+00 1.78279475e+01 9.95963735e+00 1.15063913e+01
#  4.69012305e+01 8.56205229e+00 1.44305006e+01 3.06174348e+01
#  1.01016026e+01 1.94618095e+01 3.96628129e+01 5.97238083e+01
#  3.18163759e+00 5.22332553e+01 1.35500556e+01 5.97470909e+00
#  1.22917393e+01 7.82730620e+01 1.35698259e+01 7.97232064e+00
#  2.00697255e+01 5.49256935e+00 1.57790610e+00 2.75950439e+00
#  2.74036848e+00 3.29519803e+00 2.98920132e+00 2.04816810e+01
#  4.01492714e+00 8.48278632e+00 4.54194825e+01 1.28476228e+01
#  2.20257817e+01 3.78257034e+00 4.27101962e+00 8.34544254e-01
#  3.70094688e+00 6.53096237e+00 3.89623635e+00 1.85771816e+00
#  2.57112427e+00 1.23525869e+01 4.62184413e+00 9.05962231e+00
#  1.40001037e+01 2.34491487e+01 8.02114602e-01 3.21298849e+01
#  1.97718738e+01 1.70590861e+00 4.13626940e+01 5.07338709e+01
#  1.26045655e+00 6.48353686e+00 3.28187037e+01 2.75871448e+01
#  4.07959264e+00 4.69798062e+00 9.25570220e+00 1.32532513e+01
#  1.92600367e+01 9.20625126e+00 1.24178222e+01 2.75245788e+01
#  7.47459046e-01 5.81873244e+00 2.49898375e+01 4.51153351e+01
#  1.43355822e+01 1.51905900e+01 2.26722677e+00 1.18628649e+01
#  1.52121360e+01 5.55385607e+00 6.27349224e+00 9.47329970e+00
#  4.05507215e-01 7.77449523e+00 4.75113871e+00 7.93498460e+00
#  2.55126207e+00 4.42415980e+01 1.80079763e+01 2.27326592e+01
#  3.11341806e+01 1.38007284e+01 1.81864189e+00 1.54051673e+01
#  1.76784612e+01 2.73643330e+01 1.13006930e+01 2.72969333e+00
#  6.67524361e+00 9.02229651e+00 2.07644922e+01 1.69156344e+01
#  8.80413519e+00 8.61239154e+01 1.86166602e+01 5.41589058e+00
#  2.14686009e+00 3.31776585e+00 5.64613699e+00 3.50329750e+00
#  4.12983491e+00 6.71211696e+00 3.80804867e+00 4.54150290e+01
#  1.67271425e+00 1.48682470e+01 1.05661111e+01 8.07728433e+01
#  2.37654691e+00 1.01451599e+01 6.97811933e+01 4.01248812e+01
#  3.39732607e+01 5.96550167e+00 3.74799066e+00 2.20911920e+01
#  5.30077019e+01 1.62730084e+01 1.69545512e+01 6.56950062e+00
#  2.93494752e+01 4.14155964e+00 7.82175626e+00 1.10828910e+01
#  1.41696993e+01 5.55225167e+00 2.43966544e+00 1.88639931e+01
#  6.81126737e+00 1.74090614e+01 3.35329506e+00 1.31224276e+01
#  1.52109450e+01 1.06429303e+00 8.20767203e+00 2.88698654e+00
#  1.30944518e+00 9.20240262e+01 7.78260045e+00 3.32014123e+01
#  5.87777669e+00 2.28828270e+01 2.85613245e+01 1.81089319e+01
#  1.27571329e+01 1.06151563e+01 8.58086603e+00 5.30511210e+01
#  3.55121414e+01 6.70635278e+01 2.65457084e+00 2.62510273e+01
#  5.57225453e+01 3.99911619e+00 1.37620635e+00 2.70278631e+01
#  1.70885429e+01 3.68815428e+01 3.01116493e+00 3.17210022e+01
#  4.50359546e+00 3.57430398e+00 3.58889313e+00 3.37020657e+01
#  2.18842728e+01 1.48075191e+01 8.88922803e+00 4.19440533e+01
#  9.96625499e+00 3.39216533e+01 1.15654976e+01 9.46239132e+00
#  1.24232212e+01 7.17290551e+00 2.75355463e+01 1.39720563e+01
#  5.28485062e+00 4.59667970e+01 9.68663485e+00 1.56856476e+01
#  4.73899122e+01 1.95759861e+01 2.48629232e+00 5.62123337e+01
#  1.97615386e+01 8.15652631e+00 2.99953641e+00 3.16000279e+01
#  1.93555102e+01 1.52482772e+01 4.48660666e+01 3.10798003e+01
#  3.28982640e+00 7.47125103e+00 5.71339237e+00 2.72473612e+01
#  6.82150797e-01 1.68742711e+01 2.87482743e+01 4.18733469e+01
#  8.37349187e+00 3.44361593e+01 2.34487770e+00 3.74748791e+01
#  2.72759261e+00 1.01262926e+01 3.19201073e+01 3.24843580e+00
#  5.20786045e+00 2.56208620e+01 2.54619234e+01 2.04968842e+01
#  2.36800342e+01 1.56493820e+01 5.80167399e+00 8.48366388e+00
#  4.00802549e+00 4.78175228e+01 1.75121811e+01 1.02449132e+01
#  1.23981501e+01 5.88564747e+01 3.32939100e+00 1.76488922e+01
#  1.40998888e+01 1.89068864e+01 3.65523608e-01 4.11338705e+01
#  5.37997707e+01 1.66543093e+01 2.38574148e+01 5.11493872e+01
#  2.45679491e+01 3.31021018e+00 1.71740430e+01 1.86644171e+01
#  1.10374901e+01 2.66698061e+01 5.44735377e+01 5.19575243e+01
#  1.19872859e+01 2.40357409e+00 8.37834798e+01 3.65143622e+01
#  2.66291919e+00 5.07261588e+01 4.07884786e+01 1.46310277e+01
#  1.78942757e+01 1.01832969e+01 1.12636298e+00 8.16529773e+00
#  3.24761582e+01 9.28556813e-02 8.11427793e+00 1.01555619e+01
#  1.54176605e+01 5.04785095e+01 8.50354222e+00 8.52212972e+00
#  2.67501790e+01 1.20375555e+01 5.08764947e+00 1.20456470e+01
#  3.03639844e+00 3.88109006e+00 1.37977609e+01 1.08575243e+01
#  4.92658547e+01 9.00069166e+00 1.73780477e+01 2.00078155e+01
#  2.63618897e-01 2.17853639e+01 3.92117280e+00 6.49199654e+01
#  3.21893809e+00 1.07100223e+01 1.78426875e+00 1.15361632e+02
#  1.39509373e+01 1.80963865e+01 1.38864102e+00 2.77227251e+01
#  4.71205677e+00 4.56662971e+01 4.59177656e+00 4.23140860e+00
#  7.44686837e-01 1.27757159e+01 1.66408821e+01 1.35933880e+00
#  2.98800519e+01 1.20766930e+01 1.48631531e+01 1.16236294e+01
#  1.02419640e+01 1.64032691e+01 3.37406014e+00 4.01610172e+00
#  3.95789866e+01 5.84182342e+01 9.34604375e+00 6.31462731e+00
#  2.06564653e+01 1.05097914e+01 5.14282975e-01 3.39567207e+00
#  2.51736652e+01 2.15129956e+01 5.49397158e-01 5.01985948e+00
#  5.25523158e+00 2.22882945e+01 3.98147626e-01 2.19872117e+00
#  3.21803685e+01 3.93355419e+00 2.11539818e+01 5.44097244e+00
#  2.09480067e+00 5.57239033e+00 2.56218963e+01 3.87167267e+01
#  3.54650200e+01 1.01228498e+01 2.20575356e+01 4.58786821e+00
#  6.93867177e+00 4.53319726e+01 2.61743768e-01 1.78774279e+00
#  4.66100560e+00 5.37810704e-01 4.00406007e+00 1.74953746e+01
#  1.09437264e+01 4.46372604e+01 3.40139181e+01 8.36545610e+00
#  6.00652504e+00 9.55079616e+00 1.78463550e+01 6.24123420e+00
#  1.95712449e+01 1.05327208e+01 1.60613473e+01 1.14585079e+01
#  6.97599951e+00 5.93053444e+01 2.88450901e+01 3.01908996e+00
#  4.05700986e+01 1.33664066e+01 4.49907898e+01 3.21742891e+01
#  1.10751324e+01 4.54511790e-01 6.25801096e+00 1.56017551e+01
#  2.00739466e+01 5.96509360e+00 3.00148838e+00 3.60277417e+01
#  8.32124833e+01 1.49178909e+01 3.76709727e+00 6.35752943e+00
#  3.71237748e-01 4.91377706e+01 2.50562088e+00 1.71848134e+01
#  6.40562657e+00 1.61567103e+01 2.10777727e+01 3.54087838e+01
#  4.62405055e+00 2.21134593e-01 2.94416141e+00 4.60554306e+01
#  4.14120270e+01 1.81968862e+01 1.83516744e+01 2.18746846e+01
#  3.85644057e+00 4.91641912e+01 1.08521927e+01 9.66221599e+00
#  1.46343387e+01 9.62093286e-01 3.63723410e+00 2.67907818e+01
#  1.72856551e+00 1.84840444e+01 5.63000067e+00 9.86284514e+00
#  6.81304384e+00 8.79096955e+00 2.53912797e+01 7.05143079e+00
#  1.67128706e+01 1.29271957e+01 2.17933185e+01 5.52384330e+01
#  2.63781054e+01 4.83991226e+00 6.33593576e-01 6.08338604e+00
#  1.80812130e+01 1.05590556e+00 1.37181191e+01 1.81685768e+01
#  8.13663756e+00 2.94729992e+01 2.25437830e+00 1.56221012e+00
#  2.60529482e+01 1.36834045e+01 2.33208531e+01 1.14124800e+01
#  5.65792508e+00 3.41964740e+01 3.21304313e+01 2.37289764e+01
#  6.35307230e+00 1.78432176e+01 8.95619951e+00 1.92101469e+00
#  4.98539969e+01 2.94260898e+00 6.00098131e+01 1.18120203e+01] 19.450118959304486

# %%
assert np.abs(19.45 - np.mean(x)) < 0.01

# %% [markdown]
# __б)__ Выпишите логарифмическую функцию правдоподобия на бумажке. Затем вбейте её в python.

# %%
def lnL(theta, x):
    
    # your code here
    l = np.sum(np.log(theta) - theta * x)
    
    return -l

# %%
assert np.abs(lnL(4, x) - 76414.1814) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __в)__ Оцените значение параметра $\lambda$ по сгенерированной выборке `x`. Аккуратнее выбирайте точку для инициализации параметра.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

theta_init = 0.1
res = minimize(lnL, theta_init, args = (x, ), method = 'Nelder-Mead')

# your code here
print(res.x[0])
# Out:
# 0.0514062500000001

# %%
assert np.abs(res.x[0] - 0.0514) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __г)__ Постройте график для функции правдоподобия. По оси $x$ отложите значения $\lambda$, по оси $y$ логарифм правдоподобия. Отметьте на картинке точку оптимума.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

# your code here
th_grid = np.linspace(0.01, 0.15, 100)
lnL_grid = np.array([lnL(theta, x) for theta in th_grid])

plt.plot(th_grid, lnL_grid)
plt.scatter(res.x, lnL(res.x, x))

# %% [markdown]
# __д)__ Постройте для параметра $\lambda$ асимптотический $80\%$ доверительный интервал.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

alpha = 0.2
z = stats.norm.ppf(1 - alpha / 2)

left = res.x - z * np.sqrt(1 / (len(x) * res.x**2))
right = res.x + z * np.sqrt(1 / (len(x) * res.x**2))

# your code here
print(left[0], right[0])
# Out:
# -0.736945727838394 0.8397582278383942

# %%
assert np.abs(z - 1.2815) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __е)__ Проверите на уровне значимости $1\%$ тестом отношения правдоподобия гипотезу о том, что $\lambda = 0.05$.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

lnL_un = lnL(res.x, x)
lnL_r = lnL(0.05, x)

# наблюдаемое значение статистики
LR_obs = 2 * (lnL_un - lnL_r)

# критическое значение
LR_cr = stats.chi2.ppf(0.99, 1)

# your code here
print(LR_obs, LR_cr)
# Out:
# -0.7700503701544221 6.6348966010212145

# %%
assert np.abs(lnL_un - 3967.8531) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# Справились? Значит вас ничто не может остановить реализовать подобный пайплайн для более сложной ситуации. Убедитесь в этом сами, решив задачку про «Челленджер».

# %% [markdown]
# ## Упражнение 2 (Логистическая регрессия)
#
# В этом упражнении мы оценим методом максимального правдоподобия логистическую регрессию.
#
# $28$ января $1986$ года космический шатл «Челленджер» взорвался при взлёте. Семь астронавтов, находившихся на борту, погибли. В ходе расследования причин катастрофы основной версией была неполадка с резиновыми уплотнительными кольцами в соединении с ракетными ускорителями. Для $23$ предшествовавших катастрофе полётов «Челленджера» известны температура воздуха и появление повреждений хотя бы у одного из уплотнительных колец.

# %%
df = pd.read_csv('data/challenger.csv', sep=',')
print(df.shape)
df.head()
# Out:
# (23, 3)
#          Date  Temperature  Incident
# 0  04/12/1981           66         0
# 1  11/12/1981           70         1
# 2     3/22/82           69         0
# 3  01/11/1982           68         0
# 4  04/04/1983           67         0

# %% [markdown]
# __а)__ Постройте на графиках гистограмму для распределения температуры $(Temperature)$ в ситуациях, когда хотябы одно кольцо было повреждено $(Incident = 1)$ и в ситуациях, когда ни одного повреждения не было $(Incident = 0)$.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

# your code here
sns.histplot(df[df['Incident'] == 0]['Temperature'], label = 'Incident 0')
sns.histplot(df[df['Incident'] == 1]['Temperature'], label = 'Incident 1')
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
df[df['Incident'] == 1].Temperature.mean(), df[df['Incident'] == 0].Temperature.mean()
# Out:
# (63.714285714285715, 72.125)

# %% [markdown]
# __б)__ Судя по всему, между температурой и вероятностью поломки есть взаимосвязь. Пусть вероятность поломки зависит от температуры экспоненциально:
#
# $$
# P(Incident = 1) = \frac{e^{\alpha + \beta \cdot t}}{1 + e^{\alpha + \beta \cdot t}} = \frac{1}{1 + e^{-1\cdot(\alpha + \beta \cdot t)}}
# $$
#
# Выведите функцию правдоподобия и задачу для оптимизации поиска коэффициентов $\alpha$ и  $\beta$ на бумажке, а затем вбейте её в python.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

def lnL(theta, data):
    a, b = theta
    
    # your code here
    p = 1 / (1 + np.exp(-(a + b * data['Temperature'])))
    return - np.sum(data['Incident'] * np.log(p) + (1 - data['Incident']) * np.log(1 - p))

# %%
assert np.abs(lnL([4, 0.2], df) - 294.8) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __в)__ Оцените параметры $\alpha$ и $\beta$ с помощью метода максимального правдоподобия.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

theta_init = [0, 0]
res = minimize(lnL, theta_init, args = (df,), method = 'Nelder-Mead')

# your code here
print(res.fun)
# Out:
# 10.157596343958593

# %%
assert np.abs(res.fun - 10.1576) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __г)__ С помощью теста отношения правдоподобий на уровне значимости $5\%$ проверьте гипотезу о том, что $\alpha = \beta = 0$.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

lnL_un = lnL(res.x, df)
lnL_r = lnL(theta_init, df)

LR_obs = 2 * (lnL_un - lnL_r)
LR_crit = stats.chi2.ppf(0.95, 2)

# your code here
print(LR_obs, LR_crit)
# Out:
# -11.569577617840299 5.991464547107979

# %%
assert np.abs(lnL_un - 10.1576) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# __д)__ В день катастрофы температура уплотнителя была $31$ градус по Фарингейту. Предскажите с помощью построенной модели вероятность катастрофы (для этого подставьте в формулу поиска вероятности получившиеся оценки и температуру).

# %%
xnew = 31
alpha, beta = res.x

### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

p_hat = 1 / (1 + np.exp(-(alpha + beta * xnew)))

# your code here
print(p_hat)
# Out:
# 0.9996087772675878

# %%
assert np.abs(p_hat - 0.9996) < 1e-4

# несколько похожих скрытых тестов

# %% [markdown]
# Только что мы с вами оценили логистическую регрессию. На самом деле функцию потерь, которую обычно используют для оценки логистической регрессии (logloss) можно получить из метода максимального правдоподобия. Об этом мы поговорим на следующей неделе нашего курса.
#
# __е)__ А сейчас, давайте сделаем финальный штрих и оценим ту же самую моделю с помощью пакета `statsmodels`.

# %%
import statsmodels.formula.api as smf

model = smf.logit(data=df, formula='Incident ~ 1 + Temperature').fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441635
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Incident   No. Observations:                   23
# Model:                          Logit   Df Residuals:                       21
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 02 Dec 2024   Pseudo R-squ.:                  0.2813
# Time:                        05:23:23   Log-Likelihood:                -10.158
# converged:                       True   LL-Null:                       -14.134
# Covariance Type:            nonrobust   LLR p-value:                  0.004804
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      15.0429      7.379      2.039      0.041       0.581      29.505
# Temperature    -0.2322      0.108     -2.145      0.032      -0.444      -0.020
# ===============================================================================
# """

# %% [markdown]
# Посмотрев на протокол, получившийся в результате оценивания модели ответьте на вопросы:
#
# - Чему равноо значение логарифма правдоподобия? Запишите это значение в `logLik`
# - Чему равна оценка константы $\alpha$? Запишите это значение в `alph`
# - По свойствам метода максимального правдоподобия $\hat{\beta} \sim N(\beta, \hat{\sigma}^2_{\beta})$, чему равно значение $\hat{\sigma}_{\beta}$? Запишите это значение в `std_beta`
# - Чему равно p-значение для гипотезы $H_0: \beta = 0$? Запишите это значение в `pval_beta`
# - Отвергается ли гипотеза $H_0: \beta = 0$ на $5\%$ уровне значимости? Если да, запишите в `is_h` значение `False`

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzzzzzz
# will the code be with you

logLik = round(model.llf, 3)
alph = round(model.params[0], 3)
std_beta = round(model.bse[1], 3)
pval_beta = round(model.pvalues[1], 3)
is_h = pval_beta > 0.05

# your code here
print(logLik, alph, std_beta, pval_beta, is_h)
# Out:
# -10.158 15.043 0.108 0.032 False

# %%
assert np.abs(logLik + 10.158) < 1e-4

# несколько похожих скрытых тестов
